# %%
print("hello world")
# Out:
# hello world

# %%
name = "Taha Naviwala"

# %%
name
# Out:
# 'Taha Naviwala'

# %%
type(name)
# Out:
# str

# %%
age = 20

# %%
type(age)
# Out:
# int

# %%
age = 50

# %%
age
# Out:
# 50

# %%
age + 5
# Out:
# 55

# %%
age
# Out:
# 50
